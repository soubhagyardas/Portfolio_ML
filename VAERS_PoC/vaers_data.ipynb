# %%
import pandas as pd
import glob
import os

# %%
trial_df = pd.read_csv('C:/Users/lucky/Documents/Tutorial/PoC/AllVAERSDataCSVS/2022VAERSDATA.csv', encoding = "latin-1")
trial_df.head()
# Out:
# C:\Users\lucky\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0   1996873  01/01/2022    CA      NaN      NaN      NaN   U      NaN
# 1   1996874  01/01/2022   NaN      NaN      NaN      NaN   U      NaN
# 2   1996875  01/01/2022    OH      NaN      NaN      NaN   M      NaN
# 3   1996876  01/01/2022    MS     34.0      NaN      NaN   F      NaN
# 4   1996877  01/01/2022    CT      NaN      NaN      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ... CUR_ILL  \
# 0  This spontaneous report was received from a ph...  NaN  ...     NaN
# 1  SUSPECTED CLINICAL VACCINATION FAILURE; SUSPEC...  NaN  ...     NaN
# 2  SUSPECTED CLINICAL VACCINATION FAILURE; SUSPEC...  NaN  ...     NaN
# ...

# %%
trial_df1 = pd.read_csv('C:/Users/lucky/Documents/Tutorial/PoC/AllVAERSDataCSVS/1990VAERSDATA.csv', encoding = "latin-1")
trial_df1.head()
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0     25001  07/02/1990    WI      0.2      NaN      NaN   F      NaN
# 1     25003  07/02/1990    TX      0.8      NaN      NaN   M      NaN
# 2     25004  07/02/1990    NY      0.9      NaN      NaN   M      NaN
# 3     25005  07/02/1990    OK      NaN      NaN      NaN   U      NaN
# 4     25006  07/02/1990    OH     16.0     16.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ... CUR_ILL  \
# 0  Loud intense cry with screaming for 1 1/2 hrs....  NaN  ...     NaN
# 1  Hypotonic, Hyporesponsive episode, Infant died...    Y  ...     NaN
# 2  Pt developed chills for approx. 1 hr, felt ach...  NaN  ...     NaN
# 3  7 patients within 2 weeks have reported joint ...  NaN  ...     NaN
# 4  16 yr old female feeling faint & then had seiz...  NaN  ...     NaN
#
#                            HISTORY          PRIOR_VAX   SPLTTYPE  FORM_VERS  \
# ...

# %%
non_dom_df = pd.read_csv('C:/Users/lucky/Documents/Tutorial/PoC/AllVAERSDataCSVS/NonDomesticVAERSDATA.csv', encoding = "latin-1", low_memory=False)
non_dom_df.head()
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0     25002  07/02/1990    FR     82.0      NaN      NaN   M      NaN
# 1     25010  07/02/1990    FR      1.7      NaN      NaN   M      NaN
# 2     25011  07/02/1990    FR      5.0      NaN      NaN   F      NaN
# 3     25064  07/02/1990    FR      NaN      NaN      NaN   F      NaN
# 4     25055  07/09/1990    FR     54.0      NaN      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ... CUR_ILL  \
# 0  23 hrs post vaccination, developed seizures fo...  NaN  ...     NaN
# 1  17 mon. male, received 29Oct89 MMR vaccine 1 d...    Y  ...     NaN
# 2  Approx. 1 hr /p Engerix-B vaccine given became...  NaN  ...     NaN
# 3  mother vaccinated w/ Rubella 1979. Pregancey u...  NaN  ...     NaN
# 4  Hepatic pain. Increase liver fx test.  Nause c...  NaN  ...     NaN
#
#                                              HISTORY          PRIOR_VAX  \
# ...

# %% [markdown]
# ## Reading all the files

# %%
file_path = 'C:/Users/lucky/Documents/Tutorial/PoC/AllVAERSDataCSVS'
file_list = os.listdir(file_path)
file_list
# Out:
# ['1990VAERSDATA.csv',
#  '1990VAERSSYMPTOMS.csv',
#  '1990VAERSVAX.csv',
#  '1991VAERSDATA.csv',
#  '1991VAERSSYMPTOMS.csv',
#  '1991VAERSVAX.csv',
#  '1992VAERSDATA.csv',
#  '1992VAERSSYMPTOMS.csv',
#  '1992VAERSVAX.csv',
#  '1993VAERSDATA.csv',
#  '1993VAERSSYMPTOMS.csv',
#  '1993VAERSVAX.csv',
#  '1994VAERSDATA.csv',
#  '1994VAERSSYMPTOMS.csv',
#  '1994VAERSVAX.csv',
#  '1995VAERSDATA.csv',
#  '1995VAERSSYMPTOMS.csv',
#  '1995VAERSVAX.csv',
#  '1996VAERSDATA.csv',
#  '1996VAERSSYMPTOMS.csv',
#  '1996VAERSVAX.csv',
#  '1997VAERSDATA.csv',
#  '1997VAERSSYMPTOMS.csv',
#  '1997VAERSVAX.csv',
#  '1998VAERSDATA.csv',
#  '1998VAERSSYMPTOMS.csv',
#  '1998VAERSVAX.csv',
#  '1999VAERSDATA.csv',
#  '1999VAERSSYMPTOMS.csv',
#  '1999VAERSVAX.csv',
#  '2000VAERSDATA.csv',
#  '2000VAERSSYMPTOMS.csv',
#  '2000VAERSVAX.csv',
#  '2001VAERSDATA.csv',
#  '2001VAERSSYMPTOMS.csv',
#  '2001VAERSVAX.csv',
#  '2002VAERSDATA.csv',
#  '2002VAERSSYMPTOMS.csv',
#  '2002VAERSVAX.csv',
#  '2003VAERSDATA.csv',
# ...

# %% [markdown]
# ## Reading via glob

# %%
# vaers_all_year = glob.glob('*VAERSDATA')

# %%
# setting the path for joining multiple files
files = os.path.join("C:/Users/lucky/Documents/Tutorial/PoC/AllVAERSDataCSVS", "*VAERSDATA.csv")

# list of merged files returned
files = glob.glob(files)

# %%
print("Resultant CSV after joining all CSV files at a particular location...");

# joining files with concat and read_csv
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
print(df)
# Out:
# Resultant CSV after joining all CSV files at a particular location...
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3536/1586280631.py in <module>
#       2
#       3 # joining files with concat and read_csv
# ----> 4 df = pd.concat(map(pd.read_csv, files), ignore_index=True)
#       5 print(df)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
# ...

# %% [markdown]
# ## Method 2

# %%
os.chdir("C:/Users/lucky/Documents/Tutorial/PoC/AllVAERSDataCSVS")
all_filenames = [i for i in glob.glob('*VAERSDATA.{}'.format('csv'))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f, encoding='latin-1', low_memory = False) for f in all_filenames])
#export to csv
combined_csv.to_csv( "combined_dataset.csv", index=False)

# %%
incoming_path = os.chdir("C:/Users/lucky/Documents/Tutorial/PoC/AllVAERSDataCSVS")
outgoing_path = "C:/Users/lucky/Documents/Tutorial/PoC/Combined_Dataset/"
file_str = '*VAERSDATA'
data_format = 'csv'

# %%
file_str + '.' + data_format
# Out:
# '*VAERSDATA.csv'

# %%
out_file_name = 'Combined_VAERSDATA'

# %%
print(outgoing_path + out_file_name + '.' + data_format)
# Out:
# C:/Users/lucky/Documents/Tutorial/PoC/Combined_Dataset/Combined_VAERSDATA.csv

# %%
def concat_files(in_path, file_str, encoding, data_format, out_path, out_file_name):
    all_files = [i for i in glob.glob(file_str + '.' + data_format)]
    combined_data = pd.concat([pd.read_csv(f, encoding='latin-1', low_memory = False) for f in all_files])
    
    return combined_data.to_csv(outgoing_path + out_file_name + '.' + data_format, index=False)

# %%
concat_files(incoming_path, file_str, 'latin-1', data_format, outgoing_path, out_file_name)

# %%
combined_df = pd.read_csv('C:/Users/lucky/Documents/Tutorial/PoC/combined_csv.csv', encoding = "latin-1", low_memory = False)
combined_df.head()
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0     25001  07/02/1990    WI      0.2      NaN      NaN   F      NaN
# 1     25003  07/02/1990    TX      0.8      NaN      NaN   M      NaN
# 2     25004  07/02/1990    NY      0.9      NaN      NaN   M      NaN
# 3     25005  07/02/1990    OK      NaN      NaN      NaN   U      NaN
# 4     25006  07/02/1990    OH     16.0     16.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ...  \
# 0  Loud intense cry with screaming for 1 1/2 hrs....  NaN  ...
# 1  Hypotonic, Hyporesponsive episode, Infant died...    Y  ...
# 2  Pt developed chills for approx. 1 hr, felt ach...  NaN  ...
# 3  7 patients within 2 weeks have reported joint ...  NaN  ...
# 4  16 yr old female feeling faint & then had seiz...  NaN  ...
#
#   SYMPTOMVERSION4 SYMPTOM5 SYMPTOMVERSION5 VAX_TYPE  VAX_MANU VAX_LOT  \
# 0             NaN      NaN             NaN      NaN       NaN     NaN
# ...

# %%
print(sorted(combined_df['VAERS_ID'].unique()))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
combined_df['VAERS_ID'].unique()
# Out:
# array([  25001,   25003,   25004, ..., 2498813, 2498814, 2498815],
#       dtype=int64)

# %%
combined_df[combined_df['VAERS_ID'] == 25002]
# Out:
#          VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO  SEX RPT_DATE  \
# 5917001     25002  07/02/1990    FR     82.0      NaN      NaN    M      NaN
# 6595572     25002         NaN   NaN      NaN      NaN      NaN  NaN      NaN
# 7603890     25002         NaN   NaN      NaN      NaN      NaN  NaN      NaN
#
#                                               SYMPTOM_TEXT DIED  ...  \
# 5917001  23 hrs post vaccination, developed seizures fo...  NaN  ...
# 6595572                                                NaN  NaN  ...
# 7603890                                                NaN  NaN  ...
#
#         SYMPTOMVERSION4 SYMPTOM5 SYMPTOMVERSION5 VAX_TYPE          VAX_MANU  \
# 5917001             NaN      NaN             NaN      NaN               NaN
# 6595572             NaN      NaN             NaN      NaN               NaN
# 7603890             NaN      NaN             NaN      PPV  MERCK & CO. INC.
#
#         VAX_LOT VAX_DOSE_SERIES VAX_ROUTE VAX_SITE            VAX_NAME
# ...

# %%
new_df = pd.read_csv('C:/Users/lucky/Documents/Tutorial/PoC/AllVAERSDataCSVS/combined_dataset.csv', encoding = "latin-1", low_memory = False)
new_df.head()
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0     25001  07/02/1990    WI      0.2      NaN      NaN   F      NaN
# 1     25003  07/02/1990    TX      0.8      NaN      NaN   M      NaN
# 2     25004  07/02/1990    NY      0.9      NaN      NaN   M      NaN
# 3     25005  07/02/1990    OK      NaN      NaN      NaN   U      NaN
# 4     25006  07/02/1990    OH     16.0     16.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ... CUR_ILL  \
# 0  Loud intense cry with screaming for 1 1/2 hrs....  NaN  ...     NaN
# 1  Hypotonic, Hyporesponsive episode, Infant died...    Y  ...     NaN
# 2  Pt developed chills for approx. 1 hr, felt ach...  NaN  ...     NaN
# 3  7 patients within 2 weeks have reported joint ...  NaN  ...     NaN
# 4  16 yr old female feeling faint & then had seiz...  NaN  ...     NaN
#
#                            HISTORY          PRIOR_VAX   SPLTTYPE  FORM_VERS  \
# ...

# %%
new_df[new_df['VAERS_ID'] == 25002]
# Out:
#          VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 1673991     25002  07/02/1990    FR     82.0      NaN      NaN   M      NaN
#
#                                               SYMPTOM_TEXT DIED  ... CUR_ILL  \
# 1673991  23 hrs post vaccination, developed seizures fo...  NaN  ...     NaN
#
#                                               HISTORY          PRIOR_VAX  \
# 1673991  Senile dementia, Diabetes mellitus, seizures  ~ ()~~~In patient
#
#              SPLTTYPE  FORM_VERS TODAYS_DATE BIRTH_DEFECT OFC_VISIT  \
# 1673991  WAES90040535          1         NaN          NaN       NaN
#
#         ER_ED_VISIT ALLERGIES
# 1673991         NaN       NaN
#
# [1 rows x 35 columns]

# %%
a = new_df['VAERS_ID'].unique()

# %%
a.sort()
print(a)
# Out:
# [  25001   25002   25003 ... 2498869 2498873 2498935]

# %%
len(a)
# Out:
# 2352562

# %%
vaers_data = pd.read_csv('C:/Users/lucky/Documents/Tutorial/PoC/Combined_Dataset/Combined_VAERSDATA.csv', encoding = 'latin-1', low_memory = False)

# %%
vaers_data = vaers_data.sort_values(by = ['VAERS_ID'])

# %%
vaers_data.head()
# Out:
#          VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0           25001  07/02/1990    WI      0.2      NaN      NaN   F      NaN
# 1673991     25002  07/02/1990    FR     82.0      NaN      NaN   M      NaN
# 1           25003  07/02/1990    TX      0.8      NaN      NaN   M      NaN
# 2           25004  07/02/1990    NY      0.9      NaN      NaN   M      NaN
# 3           25005  07/02/1990    OK      NaN      NaN      NaN   U      NaN
#
#                                               SYMPTOM_TEXT DIED  ... CUR_ILL  \
# 0        Loud intense cry with screaming for 1 1/2 hrs....  NaN  ...     NaN
# 1673991  23 hrs post vaccination, developed seizures fo...  NaN  ...     NaN
# 1        Hypotonic, Hyporesponsive episode, Infant died...    Y  ...     NaN
# 2        Pt developed chills for approx. 1 hr, felt ach...  NaN  ...     NaN
# 3        7 patients within 2 weeks have reported joint ...  NaN  ...     NaN
#
# ...

# %%
v_data = pd.read_csv('C:/Users/lucky/Documents/Tutorial/PoC/Combined_Dataset/Combined_VAERSDATA.csv', encoding = 'latin-1')
v_data.head()
# Out:
# C:\Users\lucky\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (7,12,15,23,27,30,31,32,33,34) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0     25001  07/02/1990    WI      0.2      NaN      NaN   F      NaN
# 1     25003  07/02/1990    TX      0.8      NaN      NaN   M      NaN
# 2     25004  07/02/1990    NY      0.9      NaN      NaN   M      NaN
# 3     25005  07/02/1990    OK      NaN      NaN      NaN   U      NaN
# 4     25006  07/02/1990    OH     16.0     16.0      NaN   F      NaN
#
#                                         SYMPTOM_TEXT DIED  ... CUR_ILL  \
# 0  Loud intense cry with screaming for 1 1/2 hrs....  NaN  ...     NaN
# 1  Hypotonic, Hyporesponsive episode, Infant died...    Y  ...     NaN
# 2  Pt developed chills for approx. 1 hr, felt ach...  NaN  ...     NaN
# ...

# %%
v_vax = pd.read_csv('C:/Users/lucky/Documents/Tutorial/PoC/Combined_Dataset/Combined_VAERSVAX.csv', encoding = 'latin-1', low_memory=False)
v_vax.head()
# Out:
#    VAERS_ID VAX_TYPE                VAX_MANU  VAX_LOT VAX_DOSE_SERIES  \
# 0     25001      DTP  CONNAUGHT LABORATORIES  9Q01042             UNK
# 1     25003      DTP    LEDERLE LABORATORIES   259962               4
# 2     25003      OPV            PFIZER\WYETH   241950               4
# 3     25004      OPV            PFIZER\WYETH   232961             UNK
# 4     25005       TD    LEDERLE LABORATORIES   247955             UNK
#
#   VAX_ROUTE VAX_SITE                     VAX_NAME
# 0        IM      NaN          DTP (NO BRAND NAME)
# 1        IM      NaN            DTP (TRI-IMMUNOL)
# 2        PO       MO  POLIO VIRUS, ORAL (ORIMUNE)
# 3       NaN      NaN  POLIO VIRUS, ORAL (ORIMUNE)
# 4        IM      NaN  TD ADSORBED (NO BRAND NAME)

# %%
v_symptom = pd.read_csv('C:/Users/lucky/Documents/Tutorial/PoC/Combined_Dataset/Combined_VAERSSYMPTOMS.csv', encoding = 'latin-1', low_memory=False)
v_symptom.head()
# Out:
#    VAERS_ID    SYMPTOM1  SYMPTOMVERSION1               SYMPTOM2  \
# 0     25001   Agitation              8.1                    NaN
# 1     25003    Delirium              8.1            Hypokinesia
# 2     25004      Chills              8.1     Dermatitis contact
# 3     25005   Arthritis              8.1  Injection site oedema
# 4     25006  Convulsion              8.1              Dizziness
#
#    SYMPTOMVERSION2                 SYMPTOM3  SYMPTOMVERSION3     SYMPTOM4  \
# 0              NaN                      NaN              NaN          NaN
# 1              8.1                Hypotonia              8.1          NaN
# 2              8.1           Oedema genital              8.1  Pelvic pain
# 3              8.1  Injection site reaction              8.1          NaN
# 4              8.1                      NaN              NaN          NaN
#
#    SYMPTOMVERSION4 SYMPTOM5  SYMPTOMVERSION5
# 0              NaN      NaN              NaN
# ...

# %%
#  df3.merge(df1, on='place_id', how='left')

# %%
# v_data.merge(v_vax, on='VAERS_ID', how=)

# %%
v_data_vax = v_data.merge(v_vax, on='VAERS_ID', how='left')
v_data_vax.head()
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0     25001  07/02/1990    WI      0.2      NaN      NaN   F      NaN
# 1     25003  07/02/1990    TX      0.8      NaN      NaN   M      NaN
# 2     25003  07/02/1990    TX      0.8      NaN      NaN   M      NaN
# 3     25004  07/02/1990    NY      0.9      NaN      NaN   M      NaN
# 4     25005  07/02/1990    OK      NaN      NaN      NaN   U      NaN
#
#                                         SYMPTOM_TEXT DIED  ... OFC_VISIT  \
# 0  Loud intense cry with screaming for 1 1/2 hrs....  NaN  ...       NaN
# 1  Hypotonic, Hyporesponsive episode, Infant died...    Y  ...       NaN
# 2  Hypotonic, Hyporesponsive episode, Infant died...    Y  ...       NaN
# 3  Pt developed chills for approx. 1 hr, felt ach...  NaN  ...       NaN
# 4  7 patients within 2 weeks have reported joint ...  NaN  ...       NaN
#
#   ER_ED_VISIT ALLERGIES VAX_TYPE                VAX_MANU  VAX_LOT  \
# ...

# %%
v_final = v_data_vax.merge(v_symptom, on = 'VAERS_ID', how = 'left')
v_final.head()
# Out:
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0     25001  07/02/1990    WI      0.2      NaN      NaN   F      NaN
# 1     25003  07/02/1990    TX      0.8      NaN      NaN   M      NaN
# 2     25003  07/02/1990    TX      0.8      NaN      NaN   M      NaN
# 3     25004  07/02/1990    NY      0.9      NaN      NaN   M      NaN
# 4     25005  07/02/1990    OK      NaN      NaN      NaN   U      NaN
#
#                                         SYMPTOM_TEXT DIED  ...   SYMPTOM1  \
# 0  Loud intense cry with screaming for 1 1/2 hrs....  NaN  ...  Agitation
# 1  Hypotonic, Hyporesponsive episode, Infant died...    Y  ...   Delirium
# 2  Hypotonic, Hyporesponsive episode, Infant died...    Y  ...   Delirium
# 3  Pt developed chills for approx. 1 hr, felt ach...  NaN  ...     Chills
# 4  7 patients within 2 weeks have reported joint ...  NaN  ...  Arthritis
#
#   SYMPTOMVERSION1               SYMPTOM2 SYMPTOMVERSION2  \
# ...

# %%
v_final.shape
# Out:
# (3791944, 52)

# %%
print('v_data - ', v_data.shape)
print('v_vax - ', v_vax.shape)
print('v_symptom - ', v_symptom.shape)
# Out:
# v_data -  (2352562, 35)
# v_vax -  (2856247, 8)
# v_symptom -  (3136524, 11)

# %%
x = v_symptom['VAERS_ID'].value_counts()

# %%
print(x)
# Out:
# 2304026    42
# 1891512    38
# 607782     38
# 2197542    32
# 2050891    32
#            ..
# 1059191     1
# 1059189     1
# 1059188     1
# 1059187     1
# 1539847     1
# Name: VAERS_ID, Length: 2352303, dtype: int64

# %%
v_symptom.loc[v_symptom['VAERS_ID'] == 2304026]
# Out:
#          VAERS_ID                                      SYMPTOM1  \
# 2999570   2304026                          Abdominal distension
# 2999571   2304026                         Anaemia megaloblastic
# 2999572   2304026                        Anti-infective therapy
# 2999573   2304026             Antimitochondrial antibody normal
# 2999574   2304026                      Antiribosomal P antibody
# 2999575   2304026         Beta-2 glycoprotein antibody negative
# 2999576   2304026                     Blood bilirubin increased
# 2999577   2304026                  Blood creatine phosphokinase
# 2999578   2304026  Blood follicle stimulating hormone increased
# 2999579   2304026                        Blood potassium normal
# 2999580   2304026                          Blood urea decreased
# 2999581   2304026                               Cardiac failure
# 2999582   2304026                 Central nervous system lesion
# 2999583   2304026                                   Chromaturia
# ...

# %%
v_vax.loc[v_vax['VAERS_ID'] == 2304026]
# Out:
#          VAERS_ID VAX_TYPE              VAX_MANU  VAX_LOT VAX_DOSE_SERIES  \
# 2750283   2304026     HPV9      MERCK & CO. INC.  T013848               1
# 2750284   2304026     HPV9      MERCK & CO. INC.  T023175               2
# 2750285   2304026     HPV9      MERCK & CO. INC.  T036299               3
# 2750286   2304026      UNK  UNKNOWN MANUFACTURER      NaN             UNK
# 2750287   2304026      UNK  UNKNOWN MANUFACTURER      NaN             UNK
# 2750288   2304026      UNK  UNKNOWN MANUFACTURER      NaN             UNK
#
#         VAX_ROUTE VAX_SITE                               VAX_NAME
# 2750283       NaN       LA                       HPV (GARDASIL 9)
# 2750284       NaN       RA                       HPV (GARDASIL 9)
# 2750285       NaN       LA                       HPV (GARDASIL 9)
# 2750286       NaN      NaN  VACCINE NOT SPECIFIED (NO BRAND NAME)
# 2750287       NaN      NaN  VACCINE NOT SPECIFIED (NO BRAND NAME)
# ...

# %%
v_data.loc[v_data['VAERS_ID'] == 2304026]
# Out:
#          VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 2251139   2304026  06/01/2022    FR     19.0      NaN      NaN   F      NaN
#
#                                               SYMPTOM_TEXT DIED  ...  \
# 2251139  megaloblastic anemia; convulsion; Alopecia; Th...    Y  ...
#
#                                        CUR_ILL HISTORY PRIOR_VAX  \
# 2251139  Pulmonary arterial pressure decreased     NaN       NaN
#
#                          SPLTTYPE  FORM_VERS TODAYS_DATE BIRTH_DEFECT  \
# 2251139  CN0095075132205CHN007736          2  05/31/2022          NaN
#
#         OFC_VISIT ER_ED_VISIT ALLERGIES
# 2251139       NaN         NaN       NaN
#
# [1 rows x 35 columns]

# %%
tr = v_final.loc[v_final['VAERS_ID'] == 2304026]

# %%
tr.to_excel(r'C:/Users/lucky/Documents/Tutorial/PoC/vaers_id_2304026.xlsx', index=False)
